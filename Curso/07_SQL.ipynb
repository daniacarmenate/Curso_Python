# %%
# Importar librerias
import pandas as pd
import seaborn as sns
from sqlalchemy import engine
from pandasql import sqldf
from IPython.display import Image

# Funcion lambda que hace escribir funciones en SQL mucho más fácil
pysqldf = lambda q: sqldf(q, globals())

# %%
# Importamos datset de jugadores de futbol
jugadores = pd.read_csv("C:/Users/dania/Documents/Python Scripts/Ficheros/players.csv")
clubes = pd.read_csv("C:/Users/dania/Documents/Python Scripts/Ficheros/clubs.csv")
valuaciones = pd.read_csv("C:/Users/dania/Documents/Python Scripts/Ficheros/player_valuations.csv")

# %%
jugadores
# Out:
#        player_id first_name          last_name                        name  \
# 0             10   Miroslav              Klose              Miroslav Klose
# 1             26      Roman       Weidenfeller          Roman Weidenfeller
# 2             65    Dimitar           Berbatov            Dimitar Berbatov
# 3             77        NaN              Lúcio                       Lúcio
# 4             80        Tom             Starke                  Tom Starke
# ...          ...        ...                ...                         ...
# 30375    1166093   Georgios  Konstantakopoulos  Georgios Konstantakopoulos
# 30376    1173042      Djibi               Seck                  Djibi Seck
# 30377    1176345  Mahamadou             Nagida            Mahamadou Nagida
# 30378    1176866      Motez            Nourani               Motez Nourani
# 30379    1186012     Bakary            Haidara              Bakary Haidara
#
#        last_season  current_club_id                 player_code  \
# ...

# %%
clubes
# Out:
#      club_id             club_code                               name  \
# 0        105       sv-darmstadt-98   Sportverein Darmstadt 1898 e. V.
# 1      11127     ural-ekaterinburg              FK Ural Yekaterinburg
# 2        114     besiktas-istanbul          Beşiktaş Jimnastik Kulübü
# 3         12                as-rom         Associazione Sportiva Roma
# 4        148     tottenham-hotspur    Tottenham Hotspur Football Club
# ..       ...                   ...                                ...
# 421    68608      cf-os-belenenses                   CF Os Belenenses
# 422      724           fc-volendam             Football Club Volendam
# 423      800      atalanta-bergamo  Atalanta Bergamasca Calcio S.p.a.
# 424      979         moreirense-fc           Moreirense Futebol Clube
# 425      984  west-bromwich-albion               West Bromwich Albion
#
#     domestic_competition_id  total_market_value  squad_size  average_age  \
# ...

# %%
valuaciones
# Out:
#         player_id        date  market_value_in_eur  current_club_id  \
# 0          405973  2000-01-20               150000             3057
# 1          342216  2001-07-20               100000             1241
# 2            3132  2003-12-09               400000              126
# 3            6893  2003-12-15               900000              984
# 4              10  2004-10-04              7000000              398
# ...           ...         ...                  ...              ...
# 464777    1073997  2024-01-08               150000               18
# 464778     361508  2024-01-10               300000               39
# 464779     705337  2024-01-10               125000            26459
# 464780     800946  2024-01-10              1000000               79
# 464781     659225  2024-01-17               100000             5724
#
#        player_club_domestic_competition_id
# 0                                      BE1
# 1                                      SC1
# ...

# %% [markdown]
# ### SQL en Python
# #### 1. Consultas Básicas

# %%
# Select * from
q = """
SELECT * FROM JUGADORES
"""
pysqldf(q)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\dania\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#
# File c:\Users\dania\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# OperationalError: no such table: JUGADORES
#
# ...

# %%
# WHERE
